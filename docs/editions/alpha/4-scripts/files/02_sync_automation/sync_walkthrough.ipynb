# %% [markdown]
# # Ticket-to-Map Sync Walkthrough
#
# Walks through normalization and the ArcGIS upsert payload without committing edits.

# %%
from pathlib import Path
import sys
ROOT=Path.cwd()
while ROOT.name!="script_files" and ROOT.parent!=ROOT: ROOT=ROOT.parent
sys.path.insert(0,str(ROOT))
from capybara.core.config import load_config
from capybara.connectors.registry import build_connector
from capybara.services.sync import ticket_attributes
cfg=load_config(ROOT.parent/"config.toml"); c=build_connector(cfg)
ticket=next(iter(c.iter_tickets()))
ticket

# %%
ticket_attributes(ticket)

# %%
# When ArcGIS is configured:
# from capybara.arcgis.client import ArcGISClient
# from capybara.arcgis.operational import OperationalLayer
# from capybara.services.sync import sync_ticket
# op=OperationalLayer(ArcGISClient.from_config(cfg).feature_layer(
#     cfg.get("arcgis.operational_item_id"),cfg.get("arcgis.operational_layer_index",0)))
# sync_ticket(ticket,op,dry_run=True)
