# %% [markdown]
# # Testing & Maintenance Workbench
#
# Explores canonical ITSM records and demonstrates reconciliation logic. Attach a configured ArcGIS operational layer to compare live records.

# %%
from pathlib import Path
import sys
ROOT=Path.cwd()
while ROOT.name!="script_files" and ROOT.parent!=ROOT: ROOT=ROOT.parent
sys.path.insert(0,str(ROOT))
from capybara.core.config import load_config
from capybara.connectors.registry import build_connector
cfg=load_config(ROOT.parent/"config.toml")
connector=build_connector(cfg)
tickets=list(connector.iter_tickets())
len(tickets)

# %%
# Inspect records that lack a usable location ID.
[t for t in tickets if not t.location_id or "UNKNOWN" in t.location_id]

# %%
# Live ArcGIS reconciliation pattern:
# from capybara.arcgis.client import ArcGISClient
# from capybara.arcgis.operational import OperationalLayer
# from capybara.services.reconciliation import compare_source_to_operational
# layer = OperationalLayer(ArcGISClient.from_config(cfg).feature_layer(
#     cfg.get("arcgis.operational_item_id"), cfg.get("arcgis.operational_layer_index",0)))
# issues = compare_source_to_operational(tickets, layer.all())
# issues[:10]
