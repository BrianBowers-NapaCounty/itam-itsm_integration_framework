# %% [markdown]
# # Connector Normalization Lab
#
# Documents the canonical contract. Use it to compare how ServiceNow, TeamDynamix, or Cherwell fields map into the same Ticket/Asset objects.

# %%
from pathlib import Path
import sys
ROOT=Path.cwd()
while ROOT.name!="script_files" and ROOT.parent!=ROOT: ROOT=ROOT.parent
sys.path.insert(0,str(ROOT))
from capybara.core.config import load_config
from capybara.connectors.registry import build_connector
cfg=load_config(ROOT.parent/"config.toml")
c=build_connector(cfg)
t=next(iter(c.iter_tickets()))
t

# %%
t.raw

# %%
# Switch general.connector in config.toml to servicenow/teamdynamix/cherwell
# and rerun. Downstream report code should remain unchanged.
