# %% [markdown]
# # Period Comparison Workbench
#
# Provides side-by-side period definitions for week/month/quarter/year comparisons and a place to compute changes from hosted metric history.

# %%
from pathlib import Path
import sys
ROOT=Path.cwd()
while ROOT.name!="script_files" and ROOT.parent!=ROOT: ROOT=ROOT.parent
sys.path.insert(0,str(ROOT))
from capybara.analytics.windows import named_window
pairs=[("wtd","previous-week"),("mtd","previous-month"),("qtd","previous-quarter"),("ytd","previous-year")]
[(named_window(a,tz_name="America/Los_Angeles"),named_window(b,tz_name="America/Los_Angeles")) for a,b in pairs]

# %%
from capybara.analytics.aggregation import compare_values
compare_values(128,151)
