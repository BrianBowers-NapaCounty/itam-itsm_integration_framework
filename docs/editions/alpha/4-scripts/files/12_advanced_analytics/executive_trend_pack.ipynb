# %% [markdown]
# # Executive Trend Pack
#
# Starter notebook for building several management trend visuals from the persistent analytics store.

# %%
metrics=[
    "tickets.active",
    "tickets.unassigned",
    "tickets.on_hold",
    "tickets.location_known_rate",
    "assets.missing",
]
metrics

# %%
# Suggested panels:
# 1. Active backlog trend (1 year)
# 2. On-hold / procurement aging (6 months)
# 3. Missing-asset exceptions (1 year)
# 4. Location-quality trend (3 months)
# 5. Sync/reconciliation reliability (last 30 days)
# 6. Facility/assignment-group comparison (WTD vs previous week)
